# %% [markdown]
# Data Focused Python
# Final Project
# name
# May 7, 2018

# %% [markdown]
# ## Part 1 Extracting data
# We extracted product data such as product name, price, and customer ratings from eBay, Walmart, and Flipkart. Methods to extract data are web scraping and web API. (Note: Amazon does not seem to permit to scrape nor to offer star ratings by API. For this reason, we did not choose Amazon in this project.)
#
# ### (1) Extracting data from eBay by web scraping

# %%
import requests
import sys
from bs4 import BeautifulSoup as bs
import time
import math
import pandas as pd

# %%
# Cited from lab 3
def get_text_from_elements(elements):
    return [e.text.strip() for e in elements]

# %%
search_word = "Samsung phones"
payload = {'_nkw':search_word}
    
r = requests.get('https://www.ebay.com/sch/i.html', params = payload)
page = r.content
soup = bs(page, "html.parser")

# Count the number of pages of the search result
num_items = soup.find_all("span", class_ = "rcnt")
num_items = get_text_from_elements(num_items)
num_items = int(num_items[-1].replace(",","")) # replace "1,234" into "1234" and convert into integer

items_per_page = 50
link_pages = int(math.ceil(num_items / items_per_page))

print("The number of items hit by the search is", num_items)
print("The number of pages is", link_pages)
# Out:
# The number of items hit by the search is 58270
# The number of pages is 1166

# %%
# Scrape the data from each search result page using for loop (this may take much time)

# Create empty lists
products_table = []

# For each search result page, get all the review rating, title, and price data
for i, page in enumerate(range(min(link_pages, 100))): # to avoid kernel dead, limit maximum pages (100 items * 50 pages)
    page_num = i + 1
    payload = {'_nkw':search_word, '_pgn': page_num}
    r = requests.get('https://www.ebay.com/sch/i.html', params = payload)
    page = r.content
    soup = bs(page, "html.parser")

    # Get product data and store in a list of "products"
    result_items = soup.find_all('div', id = "ResultSetItems")
    r_lists = range(2, items_per_page + 1)
    products = result_items[0].find_all("li", r = "1")
    for r_list in r_lists:
        product = result_items[0].find_all("li", r = str(r_list))[0] # To make class bs4.element.ResultSet into bs4.element.Tag
        products.append(product)

    
    for product in products:
        # Remove products which have not review ratings
        if len(product.find_all("div", class_ = "star-ratings")) != 0:
            # Get review rating data
            review = float(product.find('div', class_ = "star-ratings").find("a")["aria-label"].split(" ")[1])
            # Get title data
            title = product.find('h3', class_ = "lvtitle").find("a").text
            # Get Price data
            price = float(product.find('li', class_ = "lvprice prc").find("span").text.split("$")[-1].replace(",",""))
            # Merge the data
            product_table = [title, review, price]
            # Mutate the data table
            products_table.append(product_table)

            
#print(products_table) # you can print the list by this line
print("The number of obtained products is", len(products_table))
# Out:
# The number of obtained products is 3082

# %%
# Uniqueness check using 'dict'
product_name = {}
count = 0
for product in products_table:
    if product[0] not in product_name:
        product_name[product[0]] = 1
    else:
        product_name[product[0]] += 1   
print("The number of unique products is", len(product_name), "out of", len(products_table))
# Out:
# The number of unique products is 2269 out of 3082

# %%
# Convert into Pandas Data frame
import pandas as pd
products_table_df = pd.DataFrame(products_table, columns = ["Name", "Ratings", "Price"])
# Print the raw data
products_table_df
# Out:
#                                                    Name  Ratings   Price
# 0     Samsung Galaxy S7 SM-G930 - 32GB - Gold Platin...     4.41  259.90
# 1     Factory Unlocked Samsung Galaxy S7 Edge GSM LT...     4.50  399.99
# 3058  Samsung Galaxy S6 edge+ SM-G928P 32GB Sprint G...     4.77  150.36
# 3059  4.5'' Samsung Galaxy A3 SM-A300F 16GB GSM Unlo...     4.62  150.00
# 3060     Samsung - Galaxy S8+ 64GB - Orchid Gray (AT&T)     4.76  754.99
# 3061  Samsung Galaxy S7 edge SM-G935 - 32GB - Gold P...     2.40  329.99
# 3062  5.7" Samsung Galaxy Note 4 SM-N910A 16MP 32GB ...     4.35  230.00
# 3063  New listing\r\n\t\tSamsung Galaxy S4 SCH-I545 ...     4.65   25.63
# 3064  New Othr Unlocked Samsung Galaxy S8+ Plus G955...     4.64  549.99
# 3065  New Samsung Galaxy S8+ Plus G955U G955U1 Silve...     4.64  589.99
# 3066  GSM Unlocked AT&T Cricket T-Mobile Samsung S7 ...     4.57  219.99
# 3067  New Samsung Galaxy S7 Edge G935U T-Mobile AT&T...     4.63  387.99
# 3068  GSM Unlocked Samsung Galaxy S7 G930P G930 Gold...     4.41  189.99
# 3069  Verizon Samsung Galaxy S8+ Plus G955U Gray Unl...     4.76  519.99
# 3070  Near MINT GSM Unlocked Samsung Galaxy S7 G930P...     4.60  209.99
# 3071     Samsung (AT&T) 32GB NOTE 4 (UNLOCKED) bundle!!     4.36  265.00
# 3072  4.7" Samsung Galaxy Alpha SM-G850F 32GB 4G GSM...     4.43  165.75
# 3073  Samsung Galaxy S7 SM-G930 - 32GB - Gold Platin...     4.41  209.00
# 3074  \r\n\t\t\t\tSamsung Galaxy S6 SM-G920V 32GB (V...     4.57  249.95
# 3075  Samsung Galaxy S3 i747 T999  i535 16GB Network...     4.49   68.00
# 3076  Samsung Galaxy S6 Edge SM-G925P - 64GB - Black...     4.23  199.99
# 3077  Unlocked AT&T Samsung Galaxy Note 5 SM-N920A 6...     4.43  315.00
# 3078  Samsung Galaxy S8 SM-G950U - 64GB - Midnight B...     4.80  469.99
# 3079                   ATT SAMSUNG GALAXY S6 32GB BLACK     4.50  350.00
# 3080  NEW Samsung S8+ PLUS G955u 64GB 4G LTE GSM Unl...     4.64  599.95
# 3081  \r\n\t\t\t\tSamsung Galaxy S7 Edge SMG935A 32G...     4.61  379.99
#
# [3082 rows x 3 columns]

# %%
# Output to CSV file as raw data
products_table_df.to_csv("ebay_raw.csv")

# %%
# Data Cleaning
# Remove duplicated products
products_table_df2 = products_table_df.drop_duplicates("Name")

# Delele "'\r', '\n', '\t'" from Name column
products_table_df2.loc[:, "Name"] = [name.replace("\t", "") for name in products_table_df2["Name"]]
products_table_df2.loc[:, "Name"] = [name.replace("\r", "") for name in products_table_df2["Name"]]
products_table_df2.loc[:, "Name"] = [name.replace("\n", "") for name in products_table_df2["Name"]]
products_table_df2.loc[:, "Name"] = [name.replace("!!", "") for name in products_table_df2["Name"]]

# Sort by product name and reset index
products_table_df2 = products_table_df2.sort_values(by="Name")
products_table_df2 = products_table_df2.reset_index(drop=True)
# Out:
# C:\Users\hika1\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
#
# 2243  VERIZON, SAMSUNG SMOOTH SCH-U350 FLIP CELL PHO...     4.47    8.99
# 2244  VERIZON/PAGE PLUS, SAMSUNG SCH-U660 CONVOY 2 P...     4.55   10.99
# 2245  Verizon Galaxy J3 Samsung SM-J320V Smartphone ...     4.84   99.97
# 2246  Verizon Prepaid - Samsung Galaxy J7 4G LTE wit...     4.83  159.99
# 2247  Verizon Samsung Galaxy Note 5 N920V 32GB GOLD ...     4.50  245.00
# 2248  Verizon Samsung Galaxy S7 Edge G935V Black 32G...     4.67  235.00
# 2249  Verizon Samsung Galaxy S7 Edge G935V Silver 32...     4.60  231.99
# 2250  Verizon Samsung Galaxy S7 G930 Gold 32GB Andro...     4.65  169.99
# 2251  Verizon Samsung Galaxy S7 G930V Gold 32GB Andr...     4.65  167.99
# 2252  Verizon Samsung Galaxy S7 SM-G930V 32GB Gold U...     4.65  169.98
# 2253  Verizon Samsung Galaxy S8+ Plus G955U Gray Unl...     4.76  519.99
# 2254  Verizon Samsung SCH-U320 Haven Cell Phone Dark...     4.64   27.99
# 2255  Verizon Samsung SPH-i535 Galaxy S3 CDMA Androi...     4.58  198.00
# 2256  Verizon Unlocked  5.1“ Samsung Galaxy S5 G900V...     4.53  147.49
# 2257  Verizon or PagePlus Samsung SCH U750 Alias 2 3...     4.53   59.99
# 2258  Very Good Used Black Samsung Galaxy S7 32GB SM...     4.70  219.95
# 2259  Very Good Used Black Samsung Galaxy S7 32GB SM...     4.66  184.95
# 2260  Very Good Used Jet Black Samsung Galaxy Note 3...     4.54  104.95
# 2261  Very Good Used Samsung Galaxy S III SCH-i535 V...     4.65   53.95
# 2262  White AT&T SAMSUNG GALAXY S2 S II SKYROCKET SG...     4.39  288.00
# 2263  [LCD Lines] Samsung Galaxy S7 SM-G930 - 32GB -...     4.66  169.99
# 2264  [Tiny LCD Spot] Samsung Galaxy S7 Edge  32GB -...     4.60  280.00
# 2265  inbox Unlocked Samsung Galaxy Alpha SM-G850A 3...     4.48   97.75
# 2266  samsung galaxy blue s5 16gb Verizon smartphone...     4.50   30.00
# 2267                                 t mobile galaxy s3     4.64  580.00
# 2268  ♡♡♡Samsung Galaxy NOTE 4 UNLOCKED Phone Plus E...     4.42  200.00
#
# [2269 rows x 3 columns]

# %%
# Output to CSV file as processed data
products_table_df2.to_csv("ebay_clean.csv")

# %% [markdown]
# ### (2) Extracting data from Walmart by web API

# %%
import requests
import pandas as pd

# %%
# Determine a search word
search_word = "Samsung phones"

# Create a new list to store product information
product_table = pd.DataFrame()

# %%
# Extract data of 1000(=25*40) items (1st-1000th item)
# According to the Walmart API documentation, "Pagination is limited to the top 1000 items for a particular search." 
for i in range(40):
    payload = {'apiKey':'t5f6xrjyupatsqspx28aprtj', 'query':search_word, 'numItems':'25', 'start':str(25*i+1)}
    r = requests.get('http://api.walmartlabs.com/v1/search', params = payload)
    data = r.json()
    items = pd.DataFrame(data["items"], columns=['name', 'salePrice','customerRating'])
    product_table = product_table.append(items, ignore_index = True)
# 945  "for 5"" Samsung Galaxy J5 Prime On5 2016 Case...       6.49
# 946  "for 6.3"" Samsung Galaxy Note 8 note8 Case Ph...       7.99
# 947  "Value Pack + for 5"" Samsung Galaxy Amp Prime...      10.99
# 948  "for 6.2"" Samsung Galaxy S8 + PLUS Case Phone...       7.99
# 949  Value Pack + for 5.5" Samsung Galaxy J7 2016 J...      11.99
# 950  "for 5.1"" Samsung Galaxy S6 EDGE Case Phone C...       6.49
# 951  Samsung G386T Galaxy Avant MyBat TUFF Hybrid P...       8.99
# 952  "for 6.3"" Samsung Galaxy Note 8 note8 Case Ph...       7.99
# 953  "for 6.3"" Samsung Galaxy Note 8 note8 Case Ph...       7.99
# 954  CoverON Samsung Galaxy S8 Plus Case, Arc Serie...       5.49
# 955  For Samsung Galaxy Note 8 IMPACT TUFF Hybrid P...      10.95
# 956  For Samsung Galaxy Note 8 IMPACT TUFF Hybrid P...      10.95
# 957  For Samsung Galaxy Note 8 IMPACT TUFF Hybrid P...      10.95
# 958  "Value Pack Cables + for 5.8"" Samsung Galaxy ...      14.95
# 959  "for 5"" Samsung Galaxy ON5 ON5 PRO Grand ON5 ...       6.99
# 960  Value Pack + for Samsung J7 2017 Sky Pro PERX ...      11.49
# 961  "Insten Black Waterproof Bag Carrying Case Pou...       2.39
# 962  Insten Titanium Solid Dark Blue Phone Case for...       4.99
# 963  Free Corresponding Sports Arm band with Purcha...      10.99
# 964  "for 5.8"" Samsung Galaxy S8 ACTIVE Case Phone...       5.99
# 965  "Value Pack Cables + for 5.8"" Samsung Galaxy ...      11.99
# 966  "Value Pack + for 5.5"" Samsung Galaxy J7 2017...      11.99
# 967  "Value Pack + for 5"" Samsung Galaxy J3 2016 J...      10.99
#
#     customerRating
# 0            3.941
# 1            3.539
# 2            4.046
# 3            4.441
# 4             2.49
# 5            3.286
# 6            4.875
# 7              NaN
# 8              NaN
# 9            4.259
# 10             4.5
# 11            4.24
# 12             4.6
# 13           3.698
# 14             NaN
# 15           3.807
# 16           2.333
# 17           3.714
# 18           4.395
# 19             1.0
# 20             NaN
# 21             1.0
# 22            3.25
# 23             1.0
# 24             NaN
# 25             2.5
# 26           3.898
# 27           4.762
# 28             5.0
# 29           4.123
# ..             ...
# 938            NaN
# 939            NaN
# 940            NaN
# 941            NaN
# 942            NaN
# 943            NaN
# 944            NaN
# 945            NaN
# 946            NaN
# 947            NaN
# 948            NaN
# 949            NaN
# 950            NaN
# 951            NaN
# 952            NaN
# 953            NaN
# 954            NaN
# 955            NaN
# 956            NaN
# 957            NaN
# 958            NaN
# 959            NaN
# 960            NaN
# 961            4.5
# 962            NaN
# 963            NaN
# 964            NaN
# 965            NaN
# 966            4.0
# 967            NaN
#
# [968 rows x 3 columns]

# %%
# Uniqueness check using 'dict'
product_name = {}
count = 0
for product in product_table['name']:
    if product not in product_name:
        product_name[product] = 1
    else:
        product_name[product] += 1   
print("# of unique products is", len(product_name), "out of", len(product_table['name']))
# Out:
# # of unique products is 743 out of 968

# %%
# Output to CSV file as raw data
product_table.to_csv("walmart_raw.csv")

# %%
# Data Cleaning
# Change the column names
product_table.columns = ["Name", "Price", "Ratings"]

# Change the order of the columns
product_table2 = product_table.loc[:,["Name", "Ratings", "Price"]]

# Remove duplicated products
product_table2 = product_table2.drop_duplicates("Name")

# Drop rows containing null data
product_table2 = product_table2.dropna()

# Sort by product name and reset index
product_table2 = product_table2.sort_values(by="Name")
product_table2 = product_table2.reset_index(drop=True)

# %%
# Print the processed data
product_table2
# Out:
#                                                   Name Ratings   Price
# 0    "Acuvar 6.5"" inch Flexible Tripod With Univer...    4.68    5.99
# 1    "Insten Black Waterproof Bag Carrying Case Pou...     4.5    2.39
# 2    "New Galaxy S6 Edge Plus 32GB G928A by Samsung...     5.0  369.95
# 3    "New J7 Pro 2017 32GB J730GM/DS by Samsung GSM...     4.0  267.95
# 4    "Samsung Galaxy Tab A 7.0"" LTE Tablet (Factor...     4.5  185.95
# 5    "Value Pack + for 5.5"" Samsung Galaxy J7 2017...     4.0   11.99
# 6    "Value Pack for 5.5"" Samsung Galaxy J7 2017 S...     5.0   10.99
# 7    "for 5.5"" Samsung Galaxy J7 2017 sky pro J730...     3.0    8.99
# 8    100% FREE MOBILE PHONE SVC W/ FREEDOMPOP SAMSU...   2.077  195.43
# 9    A1 Bluetooth Smart Watch Phone GSM for Android...   2.667   16.99
# 10   AGPtEK Black U8 Bluetooth Smart Wrist Watch Ph...   2.296   14.99
# 11   AGPtek Bluetooth Smart Watch Phone GSM for And...   1.818   17.99
# 12   AGPtek Universal 360 Degree Rotating Magnetic ...     2.5    6.99
# 13         AT PREPAID - Samsung Galaxy Express Prime 2   4.306   99.88
# 14   AT PREPAID Samsung Galaxy Express 3 8GB Prepai...   3.721   49.00
# 15   AT PREPAID Samsung Galaxy Express Prime 2 16GB...   4.046   99.00
# 16   AT Samsung Galaxy S6 edge G925A 32GB Smartphon...   4.545  449.99
# 17   Amazingforless T-9 Premium Black Bluetooth Sma...     1.0    8.99
# 18   Aoonp 14W Foldable Solar Panel Charger with 2 ...     5.0   25.99
# 19   Arclyte Technologies MPB04043M Mobile Phone Ba...     5.0   13.95
# 20   BLACK RUBBERIZED HARD CASE + BELT CLIP HOLSTER...     4.0    9.95
# 21   BUDDIBOX Galaxy S7 ACTIVE Case Clear Phone Cov...     5.0    9.95
# 22   BUDDIBOX Galaxy S7 Case [ICE] Scratch Resistan...     3.5    8.95
# 23   BasAcc Dual USB Port 6000mAh PowerBank Portabl...   4.273   13.89
# 24   Bluetooth 4.0 Headset Wireless Earphone Univer...    3.25   14.99
# 25   Bluetooth Headphones Sport Running Wireless No...   4.727   39.98
# 26   Bluetooth Headphones, ULAK Wireless V4.1 Sport...     3.5   12.99
# 27   Bluetooth Headset, TSVWireless Earpiece Blueto...     5.0    7.49
# 28   Bluetooth Smart Watch Phone GSM for Android Sa...     1.0   16.99
# 29   Bluetooth Smart Watch Phone GSM for Android Sa...   2.526   15.99
# ..                                                 ...     ...     ...
# 166  Total Wireless Samsung Galaxy S7 4G LTE Androi...   3.375  399.00
# 167  Total Wireless Samsung Galaxy S8 64GB Prepaid ...     5.0  584.51
# 168  Total Wireless Samsung Galaxy S8 Plus LTE Prep...     4.0  689.99
# 169  Total Wireless Samsung J7 Sky Pro 16GB Prepaid...   4.875  149.99
# 170  TracFone Samsung Galaxy J3 Sky 4GB Prepaid Sma...   4.209   99.99
# 171  Tracfone Samsung Galaxy J1 Luna 4G LTE Prepaid...    3.25   69.99
# 172  Tracfone Samsung Galaxy J3 Luna Pro 4G LTE Pre...   3.667   69.99
# 173  Tracfone Samsung Galaxy J7 Sky Pro 4G LTE Prep...   4.222  119.99
# 174      Tracfone Samsung Galaxy S7 Prepaid Smartphone     3.6  503.23
# 175  U.S. Cellular Samsung Galaxy J7 16GB Prepaid S...     4.5  129.00
# 176  Universal Flip Phone Carrying Case with Belt H...   4.375   12.99
# 177  Universal Motorcycle Bicycle Holder MTB Bike H...     3.0    5.99
# 178    Urban Armor Gear Case for Samsung Galaxy Note 5     4.0   10.99
# 179  Value Pack ! for Samsung Galaxy J7 2017 sky pr...     2.0   12.99
# 180  Verizon Samsung Galaxy J3 16GB Prepaid Smartph...     4.5  126.00
# 181  Verizon Samsung Galaxy J7 16GB Prepaid Smartph...   3.952  219.00
# 182  Verizon Samsung Galaxy S5 G900V 16GB Refurbish...   3.306  124.99
# 183  Verizon Wireless Samsung Galaxy Legend 4 GB Pr...   3.607   50.00
# 184  Vertical Rugged Canvas Case Cover Holster with...     3.0    6.25
# 185  Virgin Mobile Samsung J3 Emerge Prepaid Smartp...     4.6   79.00
# 186  Virgin Mobile Samsung J7 Perx 16GB Prepaid Sma...     4.0  129.00
# 187                               Vzn Samsung Convoy 4     3.0   92.50
# 188  Walmart Family Mobile Samsung Galaxy On5 4G LT...   3.546   74.99
# 189  Walmart Family Mobile Samsung S337 Luna Pro 16...   3.286   79.99
# 190  Walmart Family Mobile Samsung Sky Pro Prepaid ...   3.714  149.99
# 191  X-DRAGON Solar Charger 10000mAh Portable Solar...     4.2   19.99
# 192  X-DRAGON Solar Charger Power Bank 15000mAh Por...     5.0   19.99
# 193  X-DRAGON Solar Charger with Foldable Solar Pan...     5.0   26.99
# 194  X-DRAGON Ultra Slim Power Bank Portable Charge...     5.0    9.99
# 195  Zizo UCASE for Samsung Galaxy S7 Hybrid Dual L...     5.0    6.99
#
# [196 rows x 3 columns]

# %%
# Output to CSV file as processed data
product_table2.to_csv("walmart_clean.csv")

# %% [markdown]
# ### (3) Extracting data from Flipkart by web scraping

# %%
import requests
import sys
from bs4 import BeautifulSoup as bs
import time

# %%
# Cited from lab 3
def get_text_from_elements(elements):
    return [e.text.strip() for e in elements]

# %%
search_word = "Samsung phones"
#payload = {'q':search_word}
payload = {"page": 1, 'q':search_word, 'viewType':'list'}

r = requests.get('http://www.flipkart.com/search', params = payload)
page = r.content
soup = bs(page, "html.parser")

# %%
# Count the number of pages of the search result
link_pages = soup.find_all("span", class_ = "_3v8VuN")
link_pages = get_text_from_elements(link_pages)
# To split the string like 'Page 3 of 26' by space, extract a row from the list of one row ('link_pages')
if link_pages == []:
    link_pages = 1
else:
    link_pages = link_pages[0].split(" ")
    link_pages = int(link_pages[-1].replace(",","")) # replace "1,234" into "1234" and convert into integer
print("The number of pages is", link_pages)
# Out:
# The number of pages is 13

# %%
# Scrape the data from each search result page using for loop

# Create empty lists
products_table = []

# For each search result page, get all the review rating, title, and price data
for i, page in enumerate(range(min(link_pages, 50))): # to avoid kernel dead, limit maximum pages (40 items * 50 pages)
    page_num = i + 1
    payload = {"page": page_num, 'q':search_word, 'viewType':'list'}
    r = requests.get('http://www.flipkart.com/search', params = payload)
    page = r.content
    soup = bs(page, "html.parser")

    # Get product data (eliminating recently reviewed items and recommended items)
#    products = soup.find_all('div', class_ = "MP_3W3 _31eJXZ")
    products = soup.find_all('div', class_ = "_1-2Iqu row") # if you search laptops, use this line
    for product in products:
        # Remove products which have not review ratings
        if len(product.find_all("div", class_ = "hGSR34 _2beYZw")) != 0:
            # Get review rating data
            review_element = product.find_all("div", class_ = "hGSR34 _2beYZw")
            review_text = review_element[0].text
            review = review_text.split(" ")[0]
            review = float(review)
            # Get title data
#            title = product.find_all("a", class_ = "_2cLu-l")[0].text
            title = product.find_all("div", class_ = "_3wU53n")[0].text # if you seach laptops, use this line
            # Get Price data
            price = product.find_all("div", class_ = "_1vC4OE")[0].text
            # Merge the data
            product_table = [title, review, price]
            # Mutate the data table
            products_table.append(product_table)
    
#print(products_table) # You can print the list by this line
print("The number of products is", len(products_table))
# Out:
# The number of products is 276

# %%
# Uniqueness check using 'dict'
product_name = {}
count = 0
for product in products_table:
    if product[0] not in product_name:
        product_name[product[0]] = 1
    else:
        product_name[product[0]] += 1   
print("The number of unique products is", len(product_name), "out of", len(products_table))
# Out:
# The number of unique products is 245 out of 276

# %%
# Convert into Pandas Data frame
import pandas as pd
products_table_df = pd.DataFrame(products_table, columns = ["Name", "Ratings", "Price"])
# Print the raw table
products_table_df
# Out:
#                                                   Name  Ratings    Price
# 0                  Samsung Galaxy On Max (Gold, 32 GB)      4.3  ₹13,900
# 1                  Samsung Galaxy On Nxt (Gold, 64 GB)      4.2  ₹12,900
# 2                 Samsung Galaxy On Max (Black, 32 GB)      4.3  ₹13,900
# 3                  Samsung Galaxy J3 Pro (Gold, 16 GB)      4.2   ₹7,490
# 4                 Samsung Galaxy On Nxt (Black, 64 GB)      4.2  ₹12,900
# 5                      Samsung Galaxy On5 (Gold, 8 GB)      4.2   ₹6,990
# 6                  Samsung Galaxy On Nxt (Gold, 16 GB)      4.2  ₹10,999
# 7                 Samsung Galaxy On Nxt (Black, 16 GB)      4.2  ₹10,999
# 8                         Samsung J7 Max (Gold, 32 GB)      4.3  ₹14,900
# 9                  Samsung Galaxy J7 Nxt (Gold, 16 GB)      4.3   ₹9,490
# 10                       Samsung J7 Max (Black, 32 GB)      4.3  ₹14,900
# 11                Samsung Galaxy J7 Pro (Black, 64 GB)      4.4  ₹18,900
# 12                                   Samsung Guru 1200      4.2   ₹1,100
# 269                                  Samsung Metro 350      4.0   ₹2,199
# 270          Samsung Galaxy A7 (Midnight Black, 16 GB)      4.1  ₹15,000
# 271           Samsung Galaxy Note 3 Neo (White, 16 GB)      4.2  ₹17,999
# 272      Samsung Galaxy Note 5 (Black Sapphire, 32 GB)      3.8  ₹30,495
# 273          Samsung Galaxy A7 (Champagne Gold, 16 GB)      4.1  ₹13,000
# 274     Samsung Galaxy S6 Edge+ (Gold Platinum, 32 GB)      4.2  ₹34,900
# 275             Samsung Galaxy A7 (Pearl White, 16 GB)      4.1  ₹15,000
#
# [276 rows x 3 columns]

# %%
# Output to CSV file as raw data
products_table_df.to_csv("flipkart_raw.csv")

# %%
# Data Cleaning
# Remove duplicated products
products_table_df2 = products_table_df.drop_duplicates("Name")

# Eliminate "₹" (Indian Rupee mark from Price) 
products_table_df2.loc[:, "Price"] = [int(price[1:].replace(",", "")) for price in products_table_df2["Price"]]

# Sort by product name and reset index
products_table_df2 = products_table_df2.sort_values(by="Name")
products_table_df2 = products_table_df2.reset_index(drop=True)
# Out:
# C:\Users\hika1\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Print the processed table
products_table_df2
# Out:
#                                               Name  Ratings  Price
# 0                                     Samsung B350      4.0   2580
# 1                          Samsung B351E/Metro 350      4.1   2800
# 2            Samsung E1207 Guru FM Dual Sim - Blue      3.3   1499
# 3                            Samsung GT 1200 R/I/M      4.0   1282
# 4        Samsung Galaxy A3 (Champagne Gold, 16 GB)      4.0   7800
# 5           Samsung Galaxy A3 (Pearl White, 16 GB)      4.0   8500
# 6                 Samsung Galaxy A5 (Black, 16 GB)      4.1  14490
# 7        Samsung Galaxy A5 (Champagne Gold, 16 GB)      4.1  11900
# 8        Samsung Galaxy A5 (Midnight Black, 16 GB)      4.1  15948
# 9           Samsung Galaxy A5 (Pearl White, 16 GB)      4.1  15993
# 10    Samsung Galaxy A5 2016 Edition (Gold, 16 GB)      4.1  15490
# 11   Samsung Galaxy A5 2016 Edition (White, 16 GB)      4.1  17990
# 12       Samsung Galaxy A5-2017 (Black Sky, 32 GB)      4.1  22900
# 13       Samsung Galaxy A5-2017 (Gold Sand, 32 GB)      4.1  28000
# 14       Samsung Galaxy A7 (Champagne Gold, 16 GB)      4.1  13000
# 15       Samsung Galaxy A7 (Midnight Black, 16 GB)      4.1  15000
# 16          Samsung Galaxy A7 (Pearl White, 16 GB)      4.1  15000
# 17   Samsung Galaxy A7 2016 Edition (Black, 16 GB)      4.0  15500
# 18    Samsung Galaxy A7 2016 Edition (Gold, 16 GB)      4.0  16990
# 19   Samsung Galaxy A7 2016 Edition (White, 16 GB)      4.0  23999
# 20       Samsung Galaxy A7-2017 (Black Sky, 32 GB)      3.9  25900
# 21       Samsung Galaxy A7-2017 (Gold Sand, 32 GB)      3.9  25900
# 22                Samsung Galaxy A8 (Black, 32 GB)      4.2  22000
# 23                 Samsung Galaxy A8 (Gold, 32 GB)      4.2  25399
# 24                Samsung Galaxy A8 (White, 32 GB)      4.2  21900
# 25            Samsung Galaxy A9 Pro (Black, 32 GB)      4.3  18990
# 26             Samsung Galaxy A9 Pro (Gold, 32 GB)      4.3  32490
# 27            Samsung Galaxy A9 Pro (White, 32 GB)      4.3  23999
# 28            Samsung Galaxy Ace NXT (Black, 4 GB)      3.7   5249
# 29    Samsung Galaxy Ace NXT (Ceramic White, 4 GB)      3.7   6150
# ..                                             ...      ...    ...
# 215               Samsung Grand Prime (Grey, 8 GB)      4.0  10899
# 216              Samsung Grand Prime (White, 8 GB)      4.0   7992
# 217            Samsung Grand Prime 4G (Gold, 8 GB)      3.9   8900
# 218                              Samsung Guru 1200      4.2   1100
# 219                            Samsung Guru E1207T      4.1   1197
# 220                           Samsung Guru FM Plus      4.1   1495
# 221                Samsung Guru FM Plus SM-B110E/D      4.2   1375
# 222                                Samsung Guru GT      4.1   1223
# 223                           Samsung Guru Music 2      4.2   1625
# 224                  Samsung Guru Music 2 SM-B310E      4.1   1849
# 225                         Samsung Guru Plus B110      4.0   1470
# 226                  Samsung J7 Duo (Black, 32 GB)      4.5  16990
# 227                   Samsung J7 Duo (Gold, 32 GB)      4.5  16990
# 228                  Samsung J7 Max (Black, 32 GB)      4.3  14900
# 229                   Samsung J7 Max (Gold, 32 GB)      4.3  14900
# 230                                  Samsung Metro      4.0   2849
# 231                              Samsung Metro 313      4.0   2355
# 232                     Samsung Metro 313 Dual Sim      4.2   2025
# 233                              Samsung Metro 350      4.0   2800
# 234                        Samsung Metro SM-B313ez      4.1   2120
# 235                               Samsung Metro XL      4.1   3225
# 236          Samsung S7 Edge (Black Pearl, 128 GB)      4.7  50050
# 237             Samsung SAMSUNG Metro 350 Dual Sim      4.1   2899
# 238                             Samsung Sm-B110E/D      4.0   1550
# 239                 Samsung Tizen Z1 (White, 4 GB)      3.7   5499
# 240                 Samsung Tizen Z3 (Black, 8 GB)      3.2   5590
# 241                  Samsung Tizen Z3 (Gold, 8 GB)      3.2   4990
# 242                       Samsung Z2 (Black, 8 GB)      3.5   4650
# 243                        Samsung Z2 (Gold, 8 GB)      3.5   4650
# 244                        Samsung Z4 (Gold, 8 GB)      3.4   5790
#
# [245 rows x 3 columns]

# %%
# Output to CSV file as processed data
products_table_df2.to_csv("flipkart_clean.csv")

# %% [markdown]
# ## Part 2 Merging the data
# We developed algorithm to merge the data from three sources. This algorithm was implemented in another tool Alteryx.

# %%
import pandas as pd

# Read the three processed data from each csv file and store in each data frame
ebay_data = pd.read_csv("ebay_clean.csv", index_col = 0)
walmart_data = pd.read_csv("walmart_clean.csv", index_col = 0)
flipkart_data = pd.read_csv("flipkart_clean.csv", index_col = 0)

# %% [markdown]
# ### (1) Outer Join of eBay data and Walmart data

# %% [markdown]
# ### (2) Left Join of the merged data and Flipkart data

# %% [markdown]
# ## Part 3 Visualizing the data

# %% [markdown]
# ### References
# - Achin Sagar, "Extracting Flipkart reviews through web scraping", Quora, accessed April 8, 2018, https://codeexperiments.quora.com/Extracting-Flipkart-reviews-through-web-scraping
# - Search API, "Walmart Open API", https://developer.walmartlabs.com/docs/read/Search_API
